# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
candidato_vereador = pd.read_csv(r"C:\Users\Stephanie\Documents\5ºSemestreFatec\LabBD\jupyterNotebook\venv\consulta_cand_2020\consulta_cand_2020_sp.csv", sep=';' , encoding='iso-8859-1')

# %%
candidato_vereador
# Out:
#        DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO    NM_TIPO_ELEICAO  \
# 0      18/10/2020   07:07:08         2020                2  ELEIÇÃO ORDINÁRIA
# 1      18/10/2020   07:07:08         2020                2  ELEIÇÃO ORDINÁRIA
# 2      18/10/2020   07:07:08         2020                2  ELEIÇÃO ORDINÁRIA
# 3      18/10/2020   07:07:08         2020                2  ELEIÇÃO ORDINÁRIA
# 4      18/10/2020   07:07:08         2020                2  ELEIÇÃO ORDINÁRIA
# ...           ...        ...          ...              ...                ...
# 93325  18/10/2020   07:07:08         2020                2  ELEIÇÃO ORDINÁRIA
# 93326  18/10/2020   07:07:08         2020                2  ELEIÇÃO ORDINÁRIA
# 93327  18/10/2020   07:07:08         2020                2  ELEIÇÃO ORDINÁRIA
# 93328  18/10/2020   07:07:08         2020                2  ELEIÇÃO ORDINÁRIA
# 93329  18/10/2020   07:07:08         2020                2  ELEIÇÃO ORDINÁRIA
#
# ...

# %%
candidato_vereador.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93330 entries, 0 to 93329
# Data columns (total 63 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   DT_GERACAO                     93330 non-null  object
#  1   HH_GERACAO                     93330 non-null  object
#  2   ANO_ELEICAO                    93330 non-null  int64
#  3   CD_TIPO_ELEICAO                93330 non-null  int64
#  4   NM_TIPO_ELEICAO                93330 non-null  object
#  5   NR_TURNO                       93330 non-null  int64
#  6   CD_ELEICAO                     93330 non-null  int64
#  7   DS_ELEICAO                     93330 non-null  object
#  8   DT_ELEICAO                     93330 non-null  object
#  9   TP_ABRANGENCIA                 93330 non-null  object
#  10  SG_UF                          93330 non-null  object
#  11  SG_UE                          93330 non-null  int64
# ...

# %%
candidato_vereador['DS_GENERO'].value_counts()
# Out:
# MASCULINO    62107
# FEMININO     31223
# Name: DS_GENERO, dtype: int64

# %%
candidato_vereador['DS_GENERO'].value_counts(normalize=True)*100
# Out:
# MASCULINO    66.545591
# FEMININO     33.454409
# Name: DS_GENERO, dtype: float64

# %%
candidato_vereador['DS_GENERO'].value_counts(normalize=True).plot(kind='bar');
