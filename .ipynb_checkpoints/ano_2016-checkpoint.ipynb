# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
candidato_vereador = pd.read_csv(r"C:\Users\Stephanie\Documents\5ºSemestreFatec\LabBD\jupyterNotebook\venv\consulta_cand_2016\consulta_cand_2016_sp.csv", sep=';' , encoding='iso-8859-1')

# %%
candidato_vereador
# Out:
#        DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO    NM_TIPO_ELEICAO  \
# 0      14/08/2020   11:17:02         2016                2  ELEIÇÃO ORDINÁRIA
# 1      14/08/2020   11:17:02         2016                2  ELEIÇÃO ORDINÁRIA
# 2      14/08/2020   11:17:02         2016                2  ELEIÇÃO ORDINÁRIA
# 3      14/08/2020   11:17:02         2016                2  ELEIÇÃO ORDINÁRIA
# 4      14/08/2020   11:17:02         2016                2  ELEIÇÃO ORDINÁRIA
# ...           ...        ...          ...              ...                ...
# 86774  14/08/2020   11:17:02         2016                2  ELEIÇÃO ORDINÁRIA
# 86775  14/08/2020   11:17:02         2016                2  ELEIÇÃO ORDINÁRIA
# 86776  14/08/2020   11:17:02         2016                2  ELEIÇÃO ORDINÁRIA
# 86777  14/08/2020   11:17:02         2016                2  ELEIÇÃO ORDINÁRIA
# 86778  14/08/2020   11:17:02         2016                2  ELEIÇÃO ORDINÁRIA
#
#        NR_TURNO  CD_ELEICAO                DS_ELEICAO  DT_ELEICAO  \
# 0             1         220  Eleições Municipais 2016  02/10/2016
# 1             1         220  Eleições Municipais 2016  02/10/2016
# 2             1         220  Eleições Municipais 2016  02/10/2016
# 3             1         220  Eleições Municipais 2016  02/10/2016
# 4             1         220  Eleições Municipais 2016  02/10/2016
# ...         ...         ...                       ...         ...
# 86774         1         220  Eleições Municipais 2016  02/10/2016
# 86775         1         220  Eleições Municipais 2016  02/10/2016
# 86776         1         220  Eleições Municipais 2016  02/10/2016
# 86777         1         220  Eleições Municipais 2016  02/10/2016
# 86778         1         220  Eleições Municipais 2016  02/10/2016
#
#       TP_ABRANGENCIA  ... DS_SIT_TOT_TURNO  ST_REELEICAO ST_DECLARAR_BENS  \
# 0          MUNICIPAL  ...         SUPLENTE             N                N
# 1          MUNICIPAL  ...         SUPLENTE             N                S
# 2          MUNICIPAL  ...       NÃO ELEITO             N                S
# 3          MUNICIPAL  ...       NÃO ELEITO             N                S
# 4          MUNICIPAL  ...         SUPLENTE             N                N
# ...              ...  ...              ...           ...              ...
# 86774      MUNICIPAL  ...         SUPLENTE             N                S
# 86775      MUNICIPAL  ...         SUPLENTE             N                S
# 86776      MUNICIPAL  ...    ELEITO POR QP             S                S
# 86777      MUNICIPAL  ...         SUPLENTE             N                S
# 86778      MUNICIPAL  ...         SUPLENTE             N                S
#
#        NR_PROTOCOLO_CANDIDATURA        NR_PROCESSO  \
# 0                    2420032016   4632920166260072
# 1                    2519352016   3755620166260018
# 2                    2411472016   3205320166260294
# 3                    2462802016   4362820166260175
# 4                    1355092016    293920166260137
# ...                         ...                ...
# 86774                2271772016   1289020166260304
# 86775                1900102016    621420166260336
# 86776                1664752016   3250220166260189
# 86777                2056132016   1753720166260119
# 86778                2255252016  10316220166260131
#
#        CD_SITUACAO_CANDIDATO_PLEITO  DS_SITUACAO_CANDIDATO_PLEITO  \
# 0                                 2                      DEFERIDO
# 1                                 2                      DEFERIDO
# 2                                 2                      DEFERIDO
# 3                                 2                      DEFERIDO
# 4                                 2                      DEFERIDO
# ...                             ...                           ...
# 86774                             2                      DEFERIDO
# 86775                             2                      DEFERIDO
# 86776                             2                      DEFERIDO
# 86777                             2                      DEFERIDO
# 86778                             2                      DEFERIDO
#
#       CD_SITUACAO_CANDIDATO_URNA DS_SITUACAO_CANDIDATO_URNA  \
# 0                              2                   DEFERIDO
# 1                              2                   DEFERIDO
# 2                              2                   DEFERIDO
# 3                              2                   DEFERIDO
# 4                              2                   DEFERIDO
# ...                          ...                        ...
# 86774                          2                   DEFERIDO
# 86775                          2                   DEFERIDO
# 86776                          2                   DEFERIDO
# 86777                          2                   DEFERIDO
# 86778                          2                   DEFERIDO
#
#       ST_CANDIDATO_INSERIDO_URNA
# 0                            SIM
# 1                            SIM
# 2                            SIM
# 3                            SIM
# 4                            SIM
# ...                          ...
# 86774                        SIM
# 86775                        SIM
# 86776                        SIM
# 86777                        SIM
# 86778                        SIM
#
# [86779 rows x 63 columns]

# %%
candidato_vereador.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86779 entries, 0 to 86778
# Data columns (total 63 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   DT_GERACAO                     86779 non-null  object
#  1   HH_GERACAO                     86779 non-null  object
#  2   ANO_ELEICAO                    86779 non-null  int64
#  3   CD_TIPO_ELEICAO                86779 non-null  int64
#  4   NM_TIPO_ELEICAO                86779 non-null  object
#  5   NR_TURNO                       86779 non-null  int64
#  6   CD_ELEICAO                     86779 non-null  int64
#  7   DS_ELEICAO                     86779 non-null  object
#  8   DT_ELEICAO                     86779 non-null  object
#  9   TP_ABRANGENCIA                 86779 non-null  object
#  10  SG_UF                          86779 non-null  object
#  11  SG_UE                          86779 non-null  int64
#  12  NM_UE                          86779 non-null  object
#  13  CD_CARGO                       86779 non-null  int64
#  14  DS_CARGO                       86779 non-null  object
#  15  SQ_CANDIDATO                   86779 non-null  int64
#  16  NR_CANDIDATO                   86779 non-null  int64
#  17  NM_CANDIDATO                   86779 non-null  object
#  18  NM_URNA_CANDIDATO              86779 non-null  object
#  19  NM_SOCIAL_CANDIDATO            86779 non-null  object
#  20  NR_CPF_CANDIDATO               86779 non-null  object
#  21  NM_EMAIL                       86779 non-null  object
#  22  CD_SITUACAO_CANDIDATURA        86779 non-null  int64
#  23  DS_SITUACAO_CANDIDATURA        86779 non-null  object
#  24  CD_DETALHE_SITUACAO_CAND       86779 non-null  int64
#  25  DS_DETALHE_SITUACAO_CAND       86779 non-null  object
#  26  TP_AGREMIACAO                  86779 non-null  object
#  27  NR_PARTIDO                     86779 non-null  int64
#  28  SG_PARTIDO                     86779 non-null  object
#  29  NM_PARTIDO                     86779 non-null  object
#  30  SQ_COLIGACAO                   86779 non-null  int64
#  31  NM_COLIGACAO                   86779 non-null  object
#  32  DS_COMPOSICAO_COLIGACAO        86779 non-null  object
#  33  CD_NACIONALIDADE               86779 non-null  int64
#  34  DS_NACIONALIDADE               86779 non-null  object
#  35  SG_UF_NASCIMENTO               86779 non-null  object
#  36  CD_MUNICIPIO_NASCIMENTO        86779 non-null  int64
#  37  NM_MUNICIPIO_NASCIMENTO        86779 non-null  object
#  38  DT_NASCIMENTO                  86760 non-null  object
#  39  NR_IDADE_DATA_POSSE            86760 non-null  float64
#  40  NR_TITULO_ELEITORAL_CANDIDATO  86779 non-null  int64
#  41  CD_GENERO                      86779 non-null  int64
#  42  DS_GENERO                      86779 non-null  object
#  43  CD_GRAU_INSTRUCAO              86779 non-null  int64
#  44  DS_GRAU_INSTRUCAO              86779 non-null  object
#  45  CD_ESTADO_CIVIL                86779 non-null  int64
#  46  DS_ESTADO_CIVIL                86779 non-null  object
#  47  CD_COR_RACA                    86779 non-null  int64
#  48  DS_COR_RACA                    86779 non-null  object
#  49  CD_OCUPACAO                    86779 non-null  int64
#  50  DS_OCUPACAO                    86779 non-null  object
#  51  VR_DESPESA_MAX_CAMPANHA        86779 non-null  int64
#  52  CD_SIT_TOT_TURNO               86779 non-null  int64
#  53  DS_SIT_TOT_TURNO               86779 non-null  object
#  54  ST_REELEICAO                   86779 non-null  object
#  55  ST_DECLARAR_BENS               86779 non-null  object
#  56  NR_PROTOCOLO_CANDIDATURA       86779 non-null  int64
#  57  NR_PROCESSO                    86779 non-null  int64
#  58  CD_SITUACAO_CANDIDATO_PLEITO   86779 non-null  int64
#  59  DS_SITUACAO_CANDIDATO_PLEITO   86779 non-null  object
#  60  CD_SITUACAO_CANDIDATO_URNA     86779 non-null  int64
#  61  DS_SITUACAO_CANDIDATO_URNA     86779 non-null  object
#  62  ST_CANDIDATO_INSERIDO_URNA     86779 non-null  object
# dtypes: float64(1), int64(26), object(36)
# memory usage: 41.7+ MB

# %%
candidato_vereador['DS_GENERO'].value_counts()
# Out:
# MASCULINO         59024
# FEMININO          27736
# NÃO DIVULGÁVEL       19
# Name: DS_GENERO, dtype: int64

# %%
candidato_vereador['DS_GENERO'].value_counts(normalize=True)*100
# Out:
# MASCULINO         68.016456
# FEMININO          31.961650
# NÃO DIVULGÁVEL     0.021895
# Name: DS_GENERO, dtype: float64

# %%
candidato_vereador['DS_GENERO'].value_counts(normalize=True).plot(kind='bar');
